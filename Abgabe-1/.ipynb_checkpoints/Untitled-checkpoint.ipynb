# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.constants as const

# %%
#Aufgabe 1
def f(x):
    return (x**3+1/3)-(x**3-1/3)
def g(x):
    return ((3+x**3/3)-(3-x**3/3))/x**3 #Hier sieht man schon das x=0 ausgeschlossen ist.

# %%
#Überprüfung des ganzzahligen Bereichs zur Bestimmung der Grenze
x_value = np.linspace(-175000,175000,350001)
for i in x_value:
    if np.abs(f(i))==0:
        ns = i
    if i<0:
        if np.abs(f(i)*3/2-1)>0.01:
            x_min=i+1
    if i>0:
        if np.abs(f(i)*3/2-1)>0.01:
            x_max=i-1
            print("Für ganzzahlige x-Werte im Bereich von ", x_min," bis ", x_max, "ist der Fehler der Formel f(x) kleiner als 1 Prozent")
            print("Für Zahlen x < ", ns, "und x > ", -ns, " ist f(x)=0")
            break
        elif i==175000:
            print("175000 ist keine Grenze")
xplot=np.linspace(int(x_min),int(x_max),int(x_max)-int(x_min)+1)
plt.plot(xplot, np.abs(f(xplot)*3/2-1)*100,'r.')
plt.xlabel('x')
plt.ylabel(r'Fehler in $\%$')
# Out:
# Für ganzzahlige x-Werte im Bereich von  -41285.0  bis  41285.0 ist der Fehler der Formel f(x) kleiner als 1 Prozent
# Für Zahlen x <  -165141.0 und x >  165141.0  ist f(x)=0
# Text(0, 0.5, 'Fehler in $\\%$')

# %%
# Logarithmische Überprüfung des (positiven) Bereichs
xplotlog=np.logspace(-8,4.615793,1000000)
#print(np.abs(f(xplotlog)*3/2-1)*100)
plt.plot(xplotlog, np.abs(f(xplotlog)*3/2-1)*100,'b-')
plt.xlabel('x')
plt.ylabel(r'Fehler in $\%$')
plt.xscale('log')

# %%
#Überprüfung von g(x)
x_value_g=np.logspace(-6,1,100000)
for i in x_value_g:
    if np.abs(g(i))==0:
        ns_g = i
    if np.abs(g(i)*3/2-1)>0.01:
            x_min_g=i
print("Für x-Werte", x_min_g, "< x ist der Fehler der Formel g(x) kleiner als 1 Prozent")
print("Für Zahlen x <", ns_g, "ist g(x)=0")
# Out:
# Für x-Werte 4.0126939241462344e-05 < x ist der Fehler der Formel g(x) kleiner als 1 Prozent
# Für Zahlen x < 8.732918589921798e-06 ist g(x)=0

# %%
plt.plot(x_value_g, np.abs(g(x_value_g)*3/2-1)*100,'b-')
plt.xlabel('x')
plt.ylabel(r'Fehler in $\%$')
plt.xscale('log')

# %%
#Aufgabe 2
alpha=const.alpha
m_e=const.physical_constants["electron mass energy equivalent in MeV"][0]
E_e=50000 #Alle Energien in MeV
gamma=E_e/m_e
beta=np.sqrt(1-1/gamma**2)
s=(2*E_e)**2 
def dsdO(theta):
    return alpha**2/s*(2+np.sin(theta)**2)/(1-beta**2*np.cos(theta)**2)
def dsdO_num(theta):
    return alpha**2/s*(2+np.sin(theta)**2)/(1/gamma**2+beta**2*np.sin(theta)**2)

# %%
pl=np.linspace(0,np.pi/180000,1000)

plt.subplot(121)
plt.plot(pl/2/np.pi*360000,dsdO(pl)*10**6,'b-')
plt.xlabel(r'$\theta/\si{\milli\degree}$')
plt.ylabel(r'$\frac{\mathrm{d}\sigma}{\mathrm{d}\Omega}/\si{\milli\meter\squared}$')
plt.subplot(122)
plt.plot(pl/2/np.pi*360000,dsdO_num(pl)*10**6,'r-')
plt.xlabel(r'$\theta/\si{\milli\degree}$')
plt.ylabel(r'$\frac{\mathrm{d}\sigma}{\mathrm{d}\Omega}/\si{\milli\meter\squared}$')
# Out:
# Text(0.5, 0, '$\\theta/\\si{\\degree}$')
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x0000022FCBBAAEA0> (for post_execute):
# ---------------------------------------------------------------------------
# ParseFatalException                       Traceback (most recent call last)
# C:\Users\Jonah\Anaconda3\lib\site-packages\matplotlib\mathtext.py in parse(self, s, fonts_object, fontsize, dpi)
#    2507         try:
# -> 2508             result = self._expression.parseString(s)
#    2509         except ParseBaseException as err:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in parseString(self, instring, parseAll)
#    1813                 # catch and re-raise exception from here, clears out pyparsing internal stack trace
# -> 1814                 raise exc
#    1815         else:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in parseString(self, instring, parseAll)
#    1803         try:
# -> 1804             loc, tokens = self._parse( instring, 0 )
#    1805             if parseAll:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1708                 try:
# -> 1709                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1710                 except ParseBaseException as pe:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1547                 try:
# -> 1548                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1549                 except IndexError:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4066         if self.expr is not None:
# -> 4067             return self.expr._parse( instring, loc, doActions, callPreParse=False )
#    4068         else:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1708                 try:
# -> 1709                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1710                 except ParseBaseException as pe:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1547                 try:
# -> 1548                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1549                 except IndexError:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    3721             else:
# -> 3722                 loc, exprtokens = e._parse( instring, loc, doActions )
#    3723             if exprtokens or exprtokens.haskeys():
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1708                 try:
# -> 1709                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1710                 except ParseBaseException as pe:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1547                 try:
# -> 1548                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1549                 except IndexError:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4360         try:
# -> 4361             return super(ZeroOrMore, self).parseImpl(instring, loc, doActions)
#    4362         except (ParseException,IndexError):
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4290             try_not_ender(instring, loc)
# -> 4291         loc, tokens = self_expr_parse( instring, loc, doActions, callPreParse=False )
#    4292         try:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1708                 try:
# -> 1709                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1710                 except ParseBaseException as pe:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1547                 try:
# -> 1548                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1549                 except IndexError:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    3704         # pre-parsed the string as part of our And pre-parsing
# -> 3705         loc, resultlist = self.exprs[0]._parse( instring, loc, doActions, callPreParse=False )
#    3706         errorStop = False
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1708                 try:
# -> 1709                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1710                 except ParseBaseException as pe:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1580                     try:
# -> 1581                         tokens = fn( instring, tokensStart, retTokens )
#    1582                     except IndexError as parse_action_exc:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in wrapper(*args)
#    1202             try:
# -> 1203                 ret = func(*args[limit[0]:])
#    1204                 foundArity[0] = True
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\matplotlib\mathtext.py in math_string(self, s, loc, toks)
#    2575     def math_string(self, s, loc, toks):
# -> 2576         return self._math_expression.parseString(toks[0][1:-1])
#    2577
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in parseString(self, instring, parseAll)
#    1813                 # catch and re-raise exception from here, clears out pyparsing internal stack trace
# -> 1814                 raise exc
#    1815         else:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in parseString(self, instring, parseAll)
#    1803         try:
# -> 1804             loc, tokens = self._parse( instring, 0 )
#    1805             if parseAll:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1708                 try:
# -> 1709                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1710                 except ParseBaseException as pe:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1547                 try:
# -> 1548                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1549                 except IndexError:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4066         if self.expr is not None:
# -> 4067             return self.expr._parse( instring, loc, doActions, callPreParse=False )
#    4068         else:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1708                 try:
# -> 1709                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1710                 except ParseBaseException as pe:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1547                 try:
# -> 1548                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1549                 except IndexError:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4300                     preloc = loc
# -> 4301                 loc, tmptokens = self_expr_parse( instring, preloc, doActions )
#    4302                 if tmptokens or tmptokens.haskeys():
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1708                 try:
# -> 1709                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1710                 except ParseBaseException as pe:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1547                 try:
# -> 1548                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1549                 except IndexError:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4066         if self.expr is not None:
# -> 4067             return self.expr._parse( instring, loc, doActions, callPreParse=False )
#    4068         else:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1708                 try:
# -> 1709                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1710                 except ParseBaseException as pe:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1547                 try:
# -> 1548                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1549                 except IndexError:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    3870             try:
# -> 3871                 ret = e._parse( instring, loc, doActions )
#    3872                 return ret
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1708                 try:
# -> 1709                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1710                 except ParseBaseException as pe:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1580                     try:
# -> 1581                         tokens = fn( instring, tokensStart, retTokens )
#    1582                     except IndexError as parse_action_exc:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in wrapper(*args)
#    1202             try:
# -> 1203                 ret = func(*args[limit[0]:])
#    1204                 foundArity[0] = True
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\matplotlib\mathtext.py in unknown_symbol(self, s, loc, toks)
#    2667         c = toks[0]
# -> 2668         raise ParseFatalException(s, loc, "Unknown symbol: %s" % c)
#    2669
#
# ParseFatalException: Unknown symbol: \si (at char 7), (line:1, col:8)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# C:\Users\Jonah\Anaconda3\lib\site-packages\matplotlib\pyplot.py in post_execute()
#     107             def post_execute():
#     108                 if matplotlib.is_interactive():
# --> 109                     draw_all()
#     110
#     111             # IPython >= 2
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\matplotlib\_pylab_helpers.py in draw_all(cls, force)
#     130         for f_mgr in cls.get_all_fig_managers():
#     131             if force or f_mgr.canvas.figure.stale:
# --> 132                 f_mgr.canvas.draw_idle()
#     133
#     134 atexit.register(Gcf.destroy_all)
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\matplotlib\backend_bases.py in draw_idle(self, *args, **kwargs)
#    1897         if not self._is_idle_drawing:
#    1898             with self._idle_draw_cntx():
# -> 1899                 self.draw(*args, **kwargs)
#    1900
#    1901     def draw_cursor(self, event):
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     400         toolbar = self.toolbar
#     401         try:
# --> 402             self.figure.draw(self.renderer)
#     403             # A GUI class may be need to update a window using this draw, so
#     404             # don't forget to call the superclass.
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1647
#    1648             mimage._draw_list_compositing_images(
# -> 1649                 renderer, self, artists, self.suppressComposite)
#    1650
#    1651             renderer.close_group('figure')
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2626             renderer.stop_rasterizing()
#    2627
# -> 2628         mimage._draw_list_compositing_images(renderer, self, artists)
#    2629
#    2630         renderer.close_group('axes')
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\matplotlib\axis.py in draw(self, renderer, *args, **kwargs)
#    1197         self._update_label_position(renderer)
#    1198
# -> 1199         self.label.draw(renderer)
#    1200
#    1201         self._update_offset_text_position(ticklabelBoxes, ticklabelBoxes2)
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\matplotlib\text.py in draw(self, renderer)
#     707
#     708         with _wrap_text(self) as textobj:
# --> 709             bbox, info, descent = textobj._get_layout(renderer)
#     710             trans = textobj.get_transform()
#     711
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\matplotlib\text.py in _get_layout(self, renderer)
#     311                 w, h, d = renderer.get_text_width_height_descent(clean_line,
#     312                                                         self._fontproperties,
# --> 313                                                         ismath=ismath)
#     314             else:
#     315                 w, h, d = 0, 0, 0
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in get_text_width_height_descent(self, s, prop, ismath)
#     212         if ismath:
#     213             ox, oy, width, height, descent, fonts, used_characters = \
# --> 214                 self.mathtext_parser.parse(s, self.dpi, prop)
#     215             return width, height, descent
#     216
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\matplotlib\mathtext.py in parse(self, s, dpi, prop)
#    3267             self.__class__._parser = Parser()
#    3268
# -> 3269         box = self._parser.parse(s, font_output, fontsize, dpi)
#    3270         font_output.set_canvas_size(box.width, box.height, box.depth)
#    3271         return font_output.get_results(box)
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\matplotlib\mathtext.py in parse(self, s, fonts_object, fontsize, dpi)
#    2511                                         err.line,
#    2512                                         " " * (err.column - 1) + "^",
# -> 2513                                         str(err)]))
#    2514         self._state_stack = None
#    2515         self._em_width_cache = {}
#
# ValueError:
# \theta/\si{\degree}
#        ^
# Unknown symbol: \si (at char 7), (line:1, col:8)
# ---------------------------------------------------------------------------
# ParseFatalException                       Traceback (most recent call last)
# C:\Users\Jonah\Anaconda3\lib\site-packages\matplotlib\mathtext.py in parse(self, s, fonts_object, fontsize, dpi)
#    2507         try:
# -> 2508             result = self._expression.parseString(s)
#    2509         except ParseBaseException as err:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in parseString(self, instring, parseAll)
#    1813                 # catch and re-raise exception from here, clears out pyparsing internal stack trace
# -> 1814                 raise exc
#    1815         else:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in parseString(self, instring, parseAll)
#    1803         try:
# -> 1804             loc, tokens = self._parse( instring, 0 )
#    1805             if parseAll:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1708                 try:
# -> 1709                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1710                 except ParseBaseException as pe:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1547                 try:
# -> 1548                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1549                 except IndexError:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4066         if self.expr is not None:
# -> 4067             return self.expr._parse( instring, loc, doActions, callPreParse=False )
#    4068         else:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1708                 try:
# -> 1709                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1710                 except ParseBaseException as pe:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1547                 try:
# -> 1548                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1549                 except IndexError:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    3721             else:
# -> 3722                 loc, exprtokens = e._parse( instring, loc, doActions )
#    3723             if exprtokens or exprtokens.haskeys():
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1708                 try:
# -> 1709                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1710                 except ParseBaseException as pe:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1547                 try:
# -> 1548                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1549                 except IndexError:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4360         try:
# -> 4361             return super(ZeroOrMore, self).parseImpl(instring, loc, doActions)
#    4362         except (ParseException,IndexError):
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4290             try_not_ender(instring, loc)
# -> 4291         loc, tokens = self_expr_parse( instring, loc, doActions, callPreParse=False )
#    4292         try:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1708                 try:
# -> 1709                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1710                 except ParseBaseException as pe:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1547                 try:
# -> 1548                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1549                 except IndexError:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    3704         # pre-parsed the string as part of our And pre-parsing
# -> 3705         loc, resultlist = self.exprs[0]._parse( instring, loc, doActions, callPreParse=False )
#    3706         errorStop = False
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1708                 try:
# -> 1709                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1710                 except ParseBaseException as pe:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1580                     try:
# -> 1581                         tokens = fn( instring, tokensStart, retTokens )
#    1582                     except IndexError as parse_action_exc:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in wrapper(*args)
#    1202             try:
# -> 1203                 ret = func(*args[limit[0]:])
#    1204                 foundArity[0] = True
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\matplotlib\mathtext.py in math_string(self, s, loc, toks)
#    2575     def math_string(self, s, loc, toks):
# -> 2576         return self._math_expression.parseString(toks[0][1:-1])
#    2577
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in parseString(self, instring, parseAll)
#    1813                 # catch and re-raise exception from here, clears out pyparsing internal stack trace
# -> 1814                 raise exc
#    1815         else:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in parseString(self, instring, parseAll)
#    1803         try:
# -> 1804             loc, tokens = self._parse( instring, 0 )
#    1805             if parseAll:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1708                 try:
# -> 1709                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1710                 except ParseBaseException as pe:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1547                 try:
# -> 1548                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1549                 except IndexError:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4066         if self.expr is not None:
# -> 4067             return self.expr._parse( instring, loc, doActions, callPreParse=False )
#    4068         else:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1708                 try:
# -> 1709                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1710                 except ParseBaseException as pe:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1547                 try:
# -> 1548                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1549                 except IndexError:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4300                     preloc = loc
# -> 4301                 loc, tmptokens = self_expr_parse( instring, preloc, doActions )
#    4302                 if tmptokens or tmptokens.haskeys():
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1708                 try:
# -> 1709                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1710                 except ParseBaseException as pe:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1547                 try:
# -> 1548                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1549                 except IndexError:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4066         if self.expr is not None:
# -> 4067             return self.expr._parse( instring, loc, doActions, callPreParse=False )
#    4068         else:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1708                 try:
# -> 1709                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1710                 except ParseBaseException as pe:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1547                 try:
# -> 1548                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1549                 except IndexError:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    3870             try:
# -> 3871                 ret = e._parse( instring, loc, doActions )
#    3872                 return ret
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1708                 try:
# -> 1709                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1710                 except ParseBaseException as pe:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1580                     try:
# -> 1581                         tokens = fn( instring, tokensStart, retTokens )
#    1582                     except IndexError as parse_action_exc:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\pyparsing.py in wrapper(*args)
#    1202             try:
# -> 1203                 ret = func(*args[limit[0]:])
#    1204                 foundArity[0] = True
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\matplotlib\mathtext.py in unknown_symbol(self, s, loc, toks)
#    2667         c = toks[0]
# -> 2668         raise ParseFatalException(s, loc, "Unknown symbol: %s" % c)
#    2669
#
# ParseFatalException: Unknown symbol: \si (at char 7), (line:1, col:8)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# C:\Users\Jonah\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     242
#     243     if 'png' in formats:
# --> 244         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     245     if 'retina' in formats or 'png2x' in formats:
#     246         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     126
#     127     bytes_io = BytesIO()
# --> 128     fig.canvas.print_figure(bytes_io, **kw)
#     129     data = bytes_io.getvalue()
#     130     if fmt == 'svg':
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2047                         orientation=orientation,
#    2048                         dryrun=True,
# -> 2049                         **kwargs)
#    2050                     renderer = self.figure._cachedRenderer
#    2051                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     508
#     509         """
# --> 510         FigureCanvasAgg.draw(self)
#     511         renderer = self.get_renderer()
#     512
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     400         toolbar = self.toolbar
#     401         try:
# --> 402             self.figure.draw(self.renderer)
#     403             # A GUI class may be need to update a window using this draw, so
#     404             # don't forget to call the superclass.
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1647
#    1648             mimage._draw_list_compositing_images(
# -> 1649                 renderer, self, artists, self.suppressComposite)
#    1650
#    1651             renderer.close_group('figure')
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2626             renderer.stop_rasterizing()
#    2627
# -> 2628         mimage._draw_list_compositing_images(renderer, self, artists)
#    2629
#    2630         renderer.close_group('axes')
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\matplotlib\axis.py in draw(self, renderer, *args, **kwargs)
#    1197         self._update_label_position(renderer)
#    1198
# -> 1199         self.label.draw(renderer)
#    1200
#    1201         self._update_offset_text_position(ticklabelBoxes, ticklabelBoxes2)
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\matplotlib\text.py in draw(self, renderer)
#     707
#     708         with _wrap_text(self) as textobj:
# --> 709             bbox, info, descent = textobj._get_layout(renderer)
#     710             trans = textobj.get_transform()
#     711
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\matplotlib\text.py in _get_layout(self, renderer)
#     311                 w, h, d = renderer.get_text_width_height_descent(clean_line,
#     312                                                         self._fontproperties,
# --> 313                                                         ismath=ismath)
#     314             else:
#     315                 w, h, d = 0, 0, 0
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in get_text_width_height_descent(self, s, prop, ismath)
#     212         if ismath:
#     213             ox, oy, width, height, descent, fonts, used_characters = \
# --> 214                 self.mathtext_parser.parse(s, self.dpi, prop)
#     215             return width, height, descent
#     216
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\matplotlib\mathtext.py in parse(self, s, dpi, prop)
#    3267             self.__class__._parser = Parser()
#    3268
# -> 3269         box = self._parser.parse(s, font_output, fontsize, dpi)
#    3270         font_output.set_canvas_size(box.width, box.height, box.depth)
#    3271         return font_output.get_results(box)
#
# C:\Users\Jonah\Anaconda3\lib\site-packages\matplotlib\mathtext.py in parse(self, s, fonts_object, fontsize, dpi)
#    2511                                         err.line,
#    2512                                         " " * (err.column - 1) + "^",
# -> 2513                                         str(err)]))
#    2514         self._state_stack = None
#    2515         self._em_width_cache = {}
#
# ValueError:
# \theta/\si{\degree}
#        ^
# Unknown symbol: \si (at char 7), (line:1, col:8)
